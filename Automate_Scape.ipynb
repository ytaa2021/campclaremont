# %%
import calendar
import datetime
from urllib.request import urlopen
import json
import requests
 
date = datetime.datetime.utcnow()
utc_time = calendar.timegm(date.utctimetuple())

# %%
import csv
import pandas as pd



def scrape(dining_hall):
  date = datetime.datetime.utcnow()
  utc_time = calendar.timegm(date.utctimetuple())
  link = "https://5cmenu-cache.jojodmo.com/v1/getMenu/?diningHall=" + str(dining_hall) + "&startTime=" + str(utc_time) + "&language=en"
  response = requests.get(link)
  data = response.json()
  return data



result_frary = scrape('frary')
result_frank = scrape('frank')
result_mudd = scrape('Hoch')
result_scripps= scrape('malott')
result_pitzer = scrape('mcconnel')
result_claremont = scrape('collins')



def utc_to_day(utc_timestamp):
    # Convert the UTC timestamp to a datetime object
    utc_datetime = datetime.datetime.utcfromtimestamp(utc_timestamp-28800) 

    # Extract the date from the datetime object and format it as a string
    day_string = utc_datetime.strftime('%Y-%m-%d')

    # Return the date string
    return day_string

curr_date = utc_to_day(utc_time)

# %%
#mudd



mudd_exhibition = []
mudd_bakery = []
mudd_grill = []
mudd_veggievalley = []
mudd_simpleservings = []
mudd_soupbar = []
mudd_specialsalad = []
mudd_saladyogurt = []

for menu in result_mudd["response"]["menu"]:
    #print(result_mudd)
    day = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    #for meal in menu["meals"].values():
    for meal in day:
      if meal['meal'] == 'BREAKFAST':
          for station in meal['stations']:
            if station['station'] == 'Exhibition':
              for menu in station['menu']:
                mudd_exhibition.append([menu['name']])
            if station['station'] == 'Bakery':
              for menu in station['menu']:
                mudd_bakery.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                mudd_grill.append([menu['name']])
            elif station['station'] == 'Simple Servings':
              for menu in station['menu']:
                mudd_simpleservings.append([menu['name']])
            elif station['station'] == 'Veggie Valley':
              for menu in station['menu']:
                mudd_veggievalley.append([menu['name']])
            elif station['station'] == 'Soup Bar':
              for menu in station['menu']:
                mudd_soupbar.append([menu['name']])
            #elif station['station'] == 'HMC Special Salad':
              #for menu in station['menu']:
                #mudd_specialsalad.append([menu['name']])
            elif station['station'] == 'Salad Bar Yogurt':
              for menu in station['menu']:
                mudd_saladyogurt.append([menu['name']])
            elif station['station'] == 'Special Salad Station':
              for menu in station['menu']:
                mudd_specialsalad.append([menu['name']])

# %%
#frary

expo = []
dessert = []
grill = []
mainline = []
saladbar = []
soup = []
for menu in result_frary["response"]["menu"]:
    day = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day:
      if meal['meal'] == 'Breakfast':
          for station in meal['stations']:
            if station['station'] == 'Expo':
              for menu in station['menu']:
                expo.append([menu['name']])
            elif station['station'] == 'Desserts':
              for menu in station['menu']:
                dessert.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                grill.append([menu['name']])
            elif station['station'] == 'Mainline':
              for menu in station['menu']:
                mainline.append([menu['name']])
            elif station['station'] == 'Salad Bar':
              for menu in station['menu']:
                saladbar.append([menu['name']])
            elif station['station'] == 'Soup':
              for menu in station['menu']:
                soup.append([menu['name']])

# %%
#scripps

scripps_soup = []
scripps_salad = []
scripps_global = []
scripps_herbivore = []
scripps_grill = []
scripps_sweets = []

for menu in result_scripps["response"]["menu"]:
    day = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day:
      if meal['meal'] == 'Breakfast':
          print(meal)
          for station in meal['stations']:
            if station['station'] == 'Soup':
              for menu in station['menu']:
                scripps_soup.append([menu['name']])
            if station['station'] == 'Salad':
              for menu in station['menu']:
                scripps_salad.append([menu['name']])
            elif station['station'] == 'Global':
              for menu in station['menu']:
                scripps_global.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                scripps_grill.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                scripps_sweets.append([menu['name']])
            elif station['station'] == 'Herbivore':
              for menu in station['menu']:
                scripps_herbivore.append([menu['name']])


print(scripps_global)
# Out:
# []

# %%
#pitzer

pitzer_comfort = []
pitzer_hotcereal = []
pitzer_global = []


for menu in result_pitzer["response"]["menu"]:
    day = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day:
      if meal['meal'] == 'Breakfast':
          print(meal)
          for station in meal['stations']:
            if station['station'] == 'Comfort':
              for menu in station['menu']:
                pitzer_comfort.append([menu['name']])
            if station['station'] == 'Soup':
              for menu in station['menu']:
                pitzer_soup.append([menu['name']])
            elif station['station'] == 'Global':
              for menu in station['menu']:
                pitzer_global.append([menu['name']])
            elif station['station'] == 'Salad':
              for menu in station['menu']:
                pitzer_salad.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                pitzer_sweets.append([menu['name']])
            elif station['station'] == 'Hot Cereal':
              for menu in station['menu']:
                pitzer_hotcereal.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                pitzer_grill.append([menu['name']])

# %%
#claremont mckenna


claremont_options = []
claremont_salad = []
claremont_grill = []
claremont_sweets = []
claremont_athome = []

for menu in result_claremont["response"]["menu"]:
    day = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day:
      if meal['meal'] == 'Breakfast':
          print(meal)
          for station in meal['stations']:
            if station['station'] == 'Options':
              for menu in station['menu']:
                claremont_options.append([menu['name']])
   
            elif station['station'] == 'Salad Bar':
              for menu in station['menu']:
                claremont_salad.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                claremont_sweets.append([menu['name']])
            elif station['station'] == 'Breakfast @ Home':
              for menu in station['menu']:
                claremont_athome.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                claremont_grill.append([menu['name']])

# %%
#pandas

import pandas as pd

df = pd.DataFrame()
df_breakfast = pd.DataFrame({'frary_dessert': [dessert],'frary_mainline': [mainline],'frary_grill': [grill],'frary_saladbar': [saladbar],'frary_soup': [soup],'mudd_exhibition': [mudd_exhibition],
                   'mudd_bakery': [mudd_bakery], 'mudd_grill': [mudd_grill],'mudd_saladyogurt': [mudd_saladyogurt], 'mudd_saladstation': [mudd_specialsalad], 'scripps_salad': [scripps_salad], 
                   'scripps_grill': [scripps_grill],'scripps_sweets': [scripps_sweets], 'scripps_global': [scripps_global], 'scripps_soup': [scripps_soup],'scripps_herbivore' : [scripps_herbivore],
                   'pitzer_hotcereal': [pitzer_hotcereal], 'pitzer_global': [pitzer_global],'pitzer_comfort' : [pitzer_comfort],
                   'claremont_athome': [claremont_athome], 'claremont_grill': [claremont_grill], 'claremont_options':[claremont_options], 'claremont_salad':[claremont_salad], 'claremont_sweets':[claremont_sweets]})

df_breakfast
# Out:
#                                        frary_dessert  \
# 0  [[Assorted Breakfast Pastries and Desserts - C...
#
#                                       frary_mainline  \
# 0  [[Pork Sausage Patty], [Chicken Apple Sausage]...
#
#                                          frary_grill  \
# 0  [[Buttermilk Pancakes], [Blueberry Pancakes], ...
#
#                                       frary_saladbar               frary_soup  \
# 0  [[Breakfast Bar - Yogurt, Fruits, Cottage Chee...  [[Gluten Free Oatmeal]]
#
#   mudd_exhibition mudd_bakery mudd_grill mudd_saladyogurt mudd_saladstation  \
# 0              []          []         []               []                []
#
#    ... scripps_soup scripps_herbivore pitzer_hotcereal pitzer_global  \
# 0  ...           []                []               []            []
#
#   pitzer_comfort claremont_athome claremont_grill claremont_options  \
# 0             []               []              []                []
#
#   claremont_salad claremont_sweets
# 0              []               []
#
# [1 rows x 24 columns]

# %% [markdown]
# # Lunch:

# %%
#lunchscripps


scripps_soup = []
scripps_salad = []
scripps_global = []
scripps_herbivore = []
scripps_grill = []
scripps_sweets = []
scripps_oasis = []
scripps_ovens = []
scripps_deli = []


for menu in result_scripps["response"]["menu"]:
    day3 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))

    for meal in day3:
      if meal['meal'] == 'Lunch':
          for station in meal['stations']:
            if station['station'] == 'Soup':
              for menu in station['menu']:
                scripps_soup.append([menu['name']])
            if station['station'] == 'Salad':
              for menu in station['menu']:
                scripps_salad.append([menu['name']])
            elif station['station'] == 'Global':
              for menu in station['menu']:
                scripps_global.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                scripps_grill.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                scripps_sweets.append([menu['name']])
            elif station['station'] == 'Herbivore':
              for menu in station['menu']:
                scripps_herbivore.append([menu['name']])
            elif station['station'] == 'Oasis':
              for menu in station['menu']:
                scripps_oasis.append([menu['name']])
            elif station['station'] == 'Ovens':
              for menu in station['menu']:
                scripps_ovens.append([menu['name']])   
            elif station['station'] == 'Deli':
              for menu in station['menu']:
                scripps_deli.append([menu['name']])  
print(scripps_deli)
# Out:
# []

# %%
#Lunchpitzer

pitzer_comfort = []
#pitzer_hotcereal = []
pitzer_global = []
pitzer_herbivore = []
pitzer_grill = []
pitzer_sweets = []
pitzer_stocks = []
pitzer_herbivore = []
pitzer_chefstable = []



for menu in result_pitzer["response"]["menu"]:
    day4 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day4:
      if meal['meal'] == 'Lunch':
          print(meal)
          for station in meal['stations']:
            if station['station'] == 'Comfort':
              for menu in station['menu']:
                pitzer_comfort.append([menu['name']])
            if station['station'] == 'Soup':
              for menu in station['menu']:
                pitzer_soup.append([menu['name']])
            elif station['station'] == 'Global':
              for menu in station['menu']:
                pitzer_global.append([menu['name']])
            elif station['station'] == 'Salad':
              for menu in station['menu']:
                pitzer_salad.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                pitzer_sweets.append([menu['name']])
            elif station['station'] == 'Hot Cereal':
              for menu in station['menu']:
                pitzer_hotcereal.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                pitzer_grill.append([menu['name']])
            elif station['station'] == "Chef's Table":
              for menu in station['menu']:
                pitzer_chefstable.append([menu['name']])
            elif station['station'] == "Stocks":
              for menu in station['menu']:
                pitzer_stocks.append([menu['name']])
            elif station['station'] == "Herbivore":
              for menu in station['menu']:
                pitzer_herbivore.append([menu['name']])

# %%
#Lunchmudd



mudd_exhibition = []
mudd_bakery = []
mudd_grill = []
mudd_veggievalley = []
mudd_simpleservings = []
mudd_soupbar = []
mudd_specialsalad = []
mudd_saladyogurt = []
mudd_hmcspecialsalad = []
mudd_appetizer = []
mudd_chef = []
mudd_misc = []
mudd_oven = []

print(result_mudd)

for menu in result_mudd["response"]["menu"]:
    #print(result_mudd)
    day2 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    #for meal in menu["meals"].values():
    for meal in day2:
      if meal['meal'] == 'LUNCH':
          for station in meal['stations']:
            if station['station'] == 'Exhibition':
              for menu in station['menu']:
                mudd_exhibition.append([menu['name']])
            if station['station'] == 'Bakery':
              for menu in station['menu']:
                mudd_bakery.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                mudd_grill.append([menu['name']])
            elif station['station'] == 'Simple Servings':
              for menu in station['menu']:
                mudd_simpleservings.append([menu['name']])
            elif station['station'] == 'Veggie Valley':
              for menu in station['menu']:
                mudd_veggievalley.append([menu['name']])
            elif station['station'] == 'Soup Bar':
              for menu in station['menu']:
                mudd_soupbar.append([menu['name']])
            #elif station['station'] == 'HMC Special Salad':
              #for menu in station['menu']:
                #mudd_specialsalad.append([menu['name']])
            elif station['station'] == 'Salad Bar Yogurt':
              for menu in station['menu']:
                mudd_saladyogurt.append([menu['name']])
            elif station['station'] == 'Special Salad Station':
              for menu in station['menu']:
                mudd_specialsalad.append([menu['name']])
            elif station['station'] == 'HMC Special Salad':
              for menu in station['menu']:
                mudd_hmcspecialsalad.append([menu['name']])
            elif station['station'] == 'Appetizer':
              for menu in station['menu']:
                mudd_appetizer.append([menu['name']])
            elif station['station'] == 'Chef Corner':
              for menu in station['menu']:
                mudd_chef.append([menu['name']])
            elif station['station'] == 'Miscellaneous':
              for menu in station['menu']:
                mudd_misc.append([menu['name']])
            elif station['station'] == 'Oven':
              for menu in station['menu']:
                mudd_oven.append([menu['name']])
            


print(mudd_misc)
# Out:
# {'request': {'time': 1678050090, 'timeElapsed': '1.524 ms'}, 'response': {'menu': [{'date': '2023-03-05T00:00:00', 'time': 1678003200, 'meals': {'brunch': {'meal': 'BRUNCH', 'startTime': 1678041000, 'endTime': 1678049100, 'stations': [{'station': 'Exhibition', 'stationOriginal': 'EXHIBITION', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Fried Tater Tots', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': False, 'calories': 252}, {'name': 'Omelet Bar', 'description': 'Cage free egg omelet with green onions, green pepper, mushrooms, spinach, tomatoes, cheddar and mozzarella cheeses', 'vegan': False, 'vegetarian': True, 'mindful': False, 'calories': 272}]}, {'station': 'Grill', 'stationOriginal': 'GRILL', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'French Toast', 'description': 'Grilled french toast spiced with cinnamon and sprinkled with powdered sugar', 'vegan': False, 'vegetarian': True, 'mindful': True, 'calories': 112}, {'name': 'Oatmeal', 'description': 'A hearty bowl of oatmeal', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 114}, {'name': 'Hard-boiled Egg', 'description': '', 'vegan': False, 'vegetarian': True, 'mindful': False, 'calories': 78}]}, {'station': 'Special Salad Station', 'stationOriginal': 'SPECIAL BAR SALAD- S', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Fresh Spinach', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 7}, {'name': 'Salad Bar', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 5}, {'name': 'Salad Bar', 'description': 'Romaine lettuce, iceberg lettuce and arugula', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 4}]}, {'station': 'Veggie Valley', 'stationOriginal': 'VEGGIE VALLEY', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Vegan Vegetable Paella', 'description': 'Carnaroli rice, green beans, artichoke hearts, zucchini, green peas, lima beans, white wine and smoked paprika', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 245}, {'name': 'Steamed Jasmine Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 157}, {'name': 'Green Beans & Stewed Tomatoes', 'description': 'Green beans, tomatoes, onions and garlic', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 32}, {'name': 'Brown Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 120}, {'name': 'Black Beans', 'description': 'Stewed black beans with onions', 'vegan': True, 'vegetarian': True, 'mindful': False, 'calories': 161}, {'name': 'Marinated Portobello With Quinoa Pilaf', 'description': 'Balsamic-sweetened portobello mushrooms with a quinoa & zucchini pilaf seasoned with fresh basil, rosemary & garlic', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 175}]}, {'station': 'Simple Servings', 'stationOriginal': 'SIMPLE SERVINGS', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Baked Sweet Potato', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 115}, {'name': 'Brown Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 120}, {'name': 'Black Beans', 'description': 'Stewed black beans with onions', 'vegan': True, 'vegetarian': True, 'mindful': False, 'calories': 161}, {'name': 'Steamed Jasmine Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 157}, {'name': 'Roasted Vegetables', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 32}, {'name': 'Roast Beef', 'description': 'Roasted top round roast beef', 'vegan': False, 'vegetarian': False, 'mindful': False, 'calories': 191}]}, {'station': 'Soup Bar', 'stationOriginal': 'SOUP BAR', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Creole Chicken Gumbo', 'description': 'Thick and spicy chicken sou ...
# []

# %%
#Lunchfrary

expo = []
dessert = []
grill = []
mainline = []
saladbar = []
soup = []

print(curr_date)
for menu in result_frary["response"]["menu"]:
    day1 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day1:
      if meal['meal'] == 'Lunch':
          for station in meal['stations']:
            if station['station'] == 'Expo':
              for menu in station['menu']:
                expo.append([menu['name']])
            elif station['station'] == 'Desserts':
              for menu in station['menu']:
                dessert.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                grill.append([menu['name']])
            elif station['station'] == 'Mainline':
              for menu in station['menu']:
                mainline.append([menu['name']])
            elif station['station'] == 'Salad Bar':
              for menu in station['menu']:
                saladbar.append([menu['name']])
            elif station['station'] == 'Soup':
              for menu in station['menu']:
                soup.append([menu['name']])

print(expo)
# Out:
# 2023-03-05
# []

# %%
#claremont mckenna

#print(result_claremont)

claremont_expo = []
claremont_salad = []
claremont_grill = []
claremont_sweets = []
claremont_athome = []
claremont_plant = []
claremont_stock = []
claremont_oven = []
claremont_oasis = []

for menu in result_claremont["response"]["menu"]:
    print(menu)
    day5 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    print(day5)
    for meal in day5:
      if meal['meal'] == 'Lunch':
          print(meal)
          for station in meal['stations']:
            if station['station'] == 'Simply Oasis':
              for menu in station['menu']:
                claremont_oasis.append([menu['name']])
            elif station['station'] == 'Stock Pot':
              for menu in station['menu']:
                claremont_stock.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                claremont_sweets.append([menu['name']])
            elif station['station'] == '@home':
              for menu in station['menu']:
                claremont_athome.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                claremont_grill.append([menu['name']])
            elif station['station'] == 'Expo':
              for menu in station['menu']:
                claremont_expo.append([menu['name']])
            elif station['station'] == 'Ovens':
              for menu in station['menu']:
                claremont_oven.append([menu['name']])
            elif station['station'] == 'Plant Forward':
              for menu in station['menu']:
                claremont_plant.append([menu['name']])
            
            
  
        
          


print(claremont_grill)
# Out:
# {'date': '2023-03-05', 'time': 1678003200, 'meals': {'brunch': {'meal': 'Brunch', 'startTime': 1678041000, 'endTime': 1678048200, 'stations': [{'station': 'Salad Bar', 'stationOriginal': 'salad bar', 'autoCollapse': True, 'menu': []}, {'station': 'Expo', 'stationOriginal': 'expo', 'autoCollapse': True, 'menu': [{'name': 'Smoothies', 'description': 'blueberries, mango, orange passionfruit | pineapple, mango, strawberry kiwi | made without added sugar | watermelon, cantaloupe, mango, pineapple', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Options', 'stationOriginal': 'options', 'autoCollapse': True, 'menu': [{'name': 'Waffle Bar', 'description': 'house batter, assorted toppings and pancake syrup', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Buttermilk Pancakes', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Biscuits + Gravy', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chicken Strips', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Grill', 'stationOriginal': 'grill', 'autoCollapse': True, 'menu': [{'name': 'Omelet Bar', 'description': 'Glaum Egg Ranch', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Tofu Scramble', 'description': 'Meiji Tofu', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Sweets', 'stationOriginal': 'sweets', 'autoCollapse': True, 'menu': [{'name': 'Sweets', 'description': 'raspberry muffins | chocolate muffins | cinnamon rolls | assorted danishes', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Vegan', 'description': 'chia seed pudding with soy', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Made Without Gluten', 'description': 'muffins | bagels', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Stock Pot', 'stationOriginal': 'stock pot', 'autoCollapse': True, 'menu': [{'name': 'Creamy Yams', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}]}, {'station': 'Simply Oasis', 'stationOriginal': 'simply oasis', 'autoCollapse': True, 'menu': [{'name': 'Roasted Pork', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Rice Pilaf', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Brussel Sprouts', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Breakfast @ Home', 'stationOriginal': 'breakfast @ home', 'autoCollapse': True, 'menu': [{'name': 'Oatmeal', 'description': 'assorted toppings', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Scrambled Cage Free Eggs', 'description': 'oil, salt', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chorizo And Eggs Scramble', 'description': 'cage free eggs, pork chorizo', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Home Fried Potatoes', 'description': 'diced potatoes, onions, bell peppers, salt, oil', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Pork Sausage Patties', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Turkey Links', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Beyond Vegan Sausage Patty', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}]}, 'dinner': {'meal': 'Dinner', 'startTime': 1678062600, 'endTime': 1678069800, 'stations': [{'station': 'Plant Forward', 'stationOriginal': 'plant forward', 'autoCollapse': True, 'menu': [{'name': 'Kung Pao Tofu', 'description': 'tofu, bell peppers, onions, MWG soy sauce, brown sugar, ginger, garlic, veggie stock', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Steamed Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Kidney Beans', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Local Vegetables', 'description': 'VR Green Farms', 'vegan': True, 'v ...
# [{'meal': 'Brunch', 'startTime': 1678041000, 'endTime': 1678048200, 'stations': [{'station': 'Salad Bar', 'stationOriginal': 'salad bar', 'autoCollapse': True, 'menu': []}, {'station': 'Expo', 'stationOriginal': 'expo', 'autoCollapse': True, 'menu': [{'name': 'Smoothies', 'description': 'blueberries, mango, orange passionfruit | pineapple, mango, strawberry kiwi | made without added sugar | watermelon, cantaloupe, mango, pineapple', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Options', 'stationOriginal': 'options', 'autoCollapse': True, 'menu': [{'name': 'Waffle Bar', 'description': 'house batter, assorted toppings and pancake syrup', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Buttermilk Pancakes', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Biscuits + Gravy', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chicken Strips', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Grill', 'stationOriginal': 'grill', 'autoCollapse': True, 'menu': [{'name': 'Omelet Bar', 'description': 'Glaum Egg Ranch', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Tofu Scramble', 'description': 'Meiji Tofu', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Sweets', 'stationOriginal': 'sweets', 'autoCollapse': True, 'menu': [{'name': 'Sweets', 'description': 'raspberry muffins | chocolate muffins | cinnamon rolls | assorted danishes', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Vegan', 'description': 'chia seed pudding with soy', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Made Without Gluten', 'description': 'muffins | bagels', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Stock Pot', 'stationOriginal': 'stock pot', 'autoCollapse': True, 'menu': [{'name': 'Creamy Yams', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}]}, {'station': 'Simply Oasis', 'stationOriginal': 'simply oasis', 'autoCollapse': True, 'menu': [{'name': 'Roasted Pork', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Rice Pilaf', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Brussel Sprouts', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Breakfast @ Home', 'stationOriginal': 'breakfast @ home', 'autoCollapse': True, 'menu': [{'name': 'Oatmeal', 'description': 'assorted toppings', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Scrambled Cage Free Eggs', 'description': 'oil, salt', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chorizo And Eggs Scramble', 'description': 'cage free eggs, pork chorizo', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Home Fried Potatoes', 'description': 'diced potatoes, onions, bell peppers, salt, oil', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Pork Sausage Patties', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Turkey Links', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Beyond Vegan Sausage Patty', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}]}, {'meal': 'Dinner', 'startTime': 1678062600, 'endTime': 1678069800, 'stations': [{'station': 'Plant Forward', 'stationOriginal': 'plant forward', 'autoCollapse': True, 'menu': [{'name': 'Kung Pao Tofu', 'description': 'tofu, bell peppers, onions, MWG soy sauce, brown sugar, ginger, garlic, veggie stock', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Steamed Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Kidney Beans', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Local Vegetables', 'description': 'VR Green Farms', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Simply Oasis', 'station ...
# []

# %%
#lunch pandas

import pandas as pd


dfLunch = pd.DataFrame({'frary_dessert': [dessert],'frary_mainline': [mainline], 'frary_expo': [expo], 'frary_grill': [grill],'frary_saladbar': [saladbar],'frary_soup': [soup],'mudd_exhibition': [mudd_exhibition],
                   'mudd_bakery': [mudd_bakery], 'mudd_grill': [mudd_grill],'mudd_saladyogurt': [mudd_saladyogurt], 'mudd_saladstation': [mudd_specialsalad], 'mudd_exhibition':[mudd_exhibition], 'mudd_veggievalley':[mudd_veggievalley], 'mudd_HMCspecialsalad':[mudd_hmcspecialsalad], 'mudd_chefscorner':[mudd_chef], 'mudd_soupbar':[mudd_soupbar],'mudd_simpleservings':[mudd_simpleservings], 'mudd_over':[mudd_oven], 'scripps_salad': [scripps_salad], 
                   'scripps_grill': [scripps_grill],'scripps_sweets': [scripps_sweets], 'scripps_global': [scripps_global], 'scripps_soup': [scripps_soup],'scripps_herbivore' : [scripps_herbivore], 'scripps_oasis':[scripps_oasis], 'scripps_ovens':[scripps_ovens],
                   'scripps_deli': [scripps_deli], 'scripps_deli': [scripps_deli],
                   'pitzer_chefstable': [pitzer_chefstable], 'pitzer_comfort':[pitzer_comfort], 'pitzer_global': [pitzer_global], 'pitzer_stocks':[pitzer_stocks],'pitzer_herbivore' : [pitzer_herbivore], 'pitzer_grill':[pitzer_grill], 
                   'claremont_athome': [claremont_athome], 'claremont_grill': [claremont_grill], 'claremont_options':[claremont_options], 'claremont_sweets':[claremont_sweets], 'claremont_plant':[claremont_plant],'claremont_stock':[claremont_stock],'claremont_oven': [claremont_oven]})

dfLunch
# Out:
#   frary_dessert frary_mainline frary_expo frary_grill frary_saladbar  \
# 0            []             []         []          []             []
#
#   frary_soup mudd_exhibition mudd_bakery mudd_grill mudd_saladyogurt  ...  \
# 0         []              []          []         []               []  ...
#
#   pitzer_stocks pitzer_herbivore pitzer_grill claremont_athome  \
# 0            []               []           []               []
#
#   claremont_grill claremont_options claremont_sweets claremont_plant  \
# 0              []                []               []              []
#
#   claremont_stock claremont_oven
# 0              []             []
#
# [1 rows x 39 columns]

# %% [markdown]
# # Dinner:

# %%
#dinnerscripps


scripps_soup = []
scripps_salad = []
scripps_global = []
scripps_herbivore = []
scripps_grill = []
scripps_sweets = []
scripps_oasis = []
scripps_ovens = []


for menu in result_scripps["response"]["menu"]:
    day3 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))

    for meal in day3:
      if meal['meal'] == 'Dinner':
          for station in meal['stations']:
            if station['station'] == 'Soup':
              for menu in station['menu']:
                scripps_soup.append([menu['name']])
            if station['station'] == 'Salad':
              for menu in station['menu']:
                scripps_salad.append([menu['name']])
            elif station['station'] == 'Global':
              for menu in station['menu']:
                scripps_global.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                scripps_grill.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                scripps_sweets.append([menu['name']])
            elif station['station'] == 'Herbivore':
              for menu in station['menu']:
                scripps_herbivore.append([menu['name']])
            elif station['station'] == 'Oasis':
              for menu in station['menu']:
                scripps_oasis.append([menu['name']])
            elif station['station'] == 'Ovens':
              for menu in station['menu']:
                scripps_ovens.append([menu['name']])    
print(scripps_grill)
# Out:
# [['Mongolian Grill'], ['Grilled Chicken'], ['Vegan Shrimp'], ['Shrimp'], ['Fresh Garlic']]

# %%
#frarydinner

expo = []
dessert = []
grill = []
mainline = []
saladbar = []
soup = []
for menu in result_frary["response"]["menu"]:
    day1 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day1:
      if meal['meal'] == 'Dinner':
          for station in meal['stations']:
            if station['station'] == 'Expo':
              for menu in station['menu']:
                expo.append([menu['name']])
            elif station['station'] == 'Desserts':
              for menu in station['menu']:
                dessert.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                grill.append([menu['name']])
            elif station['station'] == 'Mainline':
              for menu in station['menu']:
                mainline.append([menu['name']])
            elif station['station'] == 'Salad Bar':
              for menu in station['menu']:
                saladbar.append([menu['name']])
            elif station['station'] == 'Soup':
              for menu in station['menu']:
                soup.append([menu['name']])

# %%
#Dinmudd



mudd_exhibition = []
mudd_bakery = []
mudd_grill = []
mudd_veggievalley = []
mudd_simpleservings = []
mudd_soupbar = []
mudd_specialsalad = []
mudd_saladyogurt = []
mudd_hmcspecialsalad = []
mudd_appetizer = []
mudd_chef = []

print(result_mudd)

for menu in result_mudd["response"]["menu"]:
    #print(result_mudd)
    day2 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    #for meal in menu["meals"].values():
    for meal in day2:
      if meal['meal'] == 'DINNER':
          for station in meal['stations']:
            if station['station'] == 'Exhibition':
              for menu in station['menu']:
                mudd_exhibition.append([menu['name']])
            if station['station'] == 'Bakery':
              for menu in station['menu']:
                mudd_bakery.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                mudd_grill.append([menu['name']])
            elif station['station'] == 'Simple Servings':
              for menu in station['menu']:
                mudd_simpleservings.append([menu['name']])
            elif station['station'] == 'Veggie Valley':
              for menu in station['menu']:
                mudd_veggievalley.append([menu['name']])
            elif station['station'] == 'Soup Bar':
              for menu in station['menu']:
                mudd_soupbar.append([menu['name']])
            #elif station['station'] == 'HMC Special Salad':
              #for menu in station['menu']:
                #mudd_specialsalad.append([menu['name']])
            elif station['station'] == 'Salad Bar Yogurt':
              for menu in station['menu']:
                mudd_saladyogurt.append([menu['name']])
            elif station['station'] == 'Special Salad Station':
              for menu in station['menu']:
                mudd_specialsalad.append([menu['name']])
            elif station['station'] == 'HMC Special Salad':
              for menu in station['menu']:
                mudd_hmcspecialsalad.append([menu['name']])
            elif station['station'] == 'Appetizer':
              for menu in station['menu']:
                mudd_appetizer.append([menu['name']])
            elif station['station'] == 'Chef Corner':
              for menu in station['menu']:
                mudd_chef.append([menu['name']])
            


print(mudd_grill)
# Out:
# {'request': {'time': 1678050090, 'timeElapsed': '1.524 ms'}, 'response': {'menu': [{'date': '2023-03-05T00:00:00', 'time': 1678003200, 'meals': {'brunch': {'meal': 'BRUNCH', 'startTime': 1678041000, 'endTime': 1678049100, 'stations': [{'station': 'Exhibition', 'stationOriginal': 'EXHIBITION', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Fried Tater Tots', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': False, 'calories': 252}, {'name': 'Omelet Bar', 'description': 'Cage free egg omelet with green onions, green pepper, mushrooms, spinach, tomatoes, cheddar and mozzarella cheeses', 'vegan': False, 'vegetarian': True, 'mindful': False, 'calories': 272}]}, {'station': 'Grill', 'stationOriginal': 'GRILL', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'French Toast', 'description': 'Grilled french toast spiced with cinnamon and sprinkled with powdered sugar', 'vegan': False, 'vegetarian': True, 'mindful': True, 'calories': 112}, {'name': 'Oatmeal', 'description': 'A hearty bowl of oatmeal', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 114}, {'name': 'Hard-boiled Egg', 'description': '', 'vegan': False, 'vegetarian': True, 'mindful': False, 'calories': 78}]}, {'station': 'Special Salad Station', 'stationOriginal': 'SPECIAL BAR SALAD- S', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Fresh Spinach', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 7}, {'name': 'Salad Bar', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 5}, {'name': 'Salad Bar', 'description': 'Romaine lettuce, iceberg lettuce and arugula', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 4}]}, {'station': 'Veggie Valley', 'stationOriginal': 'VEGGIE VALLEY', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Vegan Vegetable Paella', 'description': 'Carnaroli rice, green beans, artichoke hearts, zucchini, green peas, lima beans, white wine and smoked paprika', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 245}, {'name': 'Steamed Jasmine Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 157}, {'name': 'Green Beans & Stewed Tomatoes', 'description': 'Green beans, tomatoes, onions and garlic', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 32}, {'name': 'Brown Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 120}, {'name': 'Black Beans', 'description': 'Stewed black beans with onions', 'vegan': True, 'vegetarian': True, 'mindful': False, 'calories': 161}, {'name': 'Marinated Portobello With Quinoa Pilaf', 'description': 'Balsamic-sweetened portobello mushrooms with a quinoa & zucchini pilaf seasoned with fresh basil, rosemary & garlic', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 175}]}, {'station': 'Simple Servings', 'stationOriginal': 'SIMPLE SERVINGS', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Baked Sweet Potato', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 115}, {'name': 'Brown Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 120}, {'name': 'Black Beans', 'description': 'Stewed black beans with onions', 'vegan': True, 'vegetarian': True, 'mindful': False, 'calories': 161}, {'name': 'Steamed Jasmine Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 157}, {'name': 'Roasted Vegetables', 'description': '', 'vegan': True, 'vegetarian': True, 'mindful': True, 'calories': 32}, {'name': 'Roast Beef', 'description': 'Roasted top round roast beef', 'vegan': False, 'vegetarian': False, 'mindful': False, 'calories': 191}]}, {'station': 'Soup Bar', 'stationOriginal': 'SOUP BAR', 'startTime': 1678041000, 'endTime': 1678049100, 'menu': [{'name': 'Creole Chicken Gumbo', 'description': 'Thick and spicy chicken sou ...
# [['Mac & Cheese Dog'], ['Mini Chicken Corndog'], ['Bacon, Mac & Cheese Hot Dog']]

# %%
#Dinnerpitzer

#pitzer_hotcereal = []
pitzer_global = []
pitzer_herbivore = []
pitzer_grill = []
pitzer_sweets = []
pitzer_stocks = []
pitzer_herbivore = []
pitzer_chefstable = []



for menu in result_pitzer["response"]["menu"]:
    day4 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    for meal in day4:
      if meal['meal'] == 'Dinner':
          print(meal)
          for station in meal['stations']:
            if station['station'] == 'Comfort':
              for menu in station['menu']:
                pitzer_comfort.append([menu['name']])
            if station['station'] == 'Soup':
              for menu in station['menu']:
                pitzer_soup.append([menu['name']])
            elif station['station'] == 'Global':
              for menu in station['menu']:
                pitzer_global.append([menu['name']])
            elif station['station'] == 'Salad':
              for menu in station['menu']:
                pitzer_salad.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                pitzer_sweets.append([menu['name']])
            elif station['station'] == 'Hot Cereal':
              for menu in station['menu']:
                pitzer_hotcereal.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                pitzer_grill.append([menu['name']])
            elif station['station'] == "Chef's Table":
              for menu in station['menu']:
                pitzer_chefstable.append([menu['name']])
# Out:
# {'meal': 'Dinner', 'startTime': 1678064400, 'endTime': 1678071600, 'stations': [{'station': 'Herbivore', 'stationOriginal': 'herbivore', 'autoCollapse': True, 'menu': [{'name': 'Wild Rice Stuffed Cabbage Rolls', 'description': 'with tofu, yellow tomato coulis', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Roasted Sweet Potatoes', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Roasted Turnips', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Rice Flour Bread Balls', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Comfort', 'stationOriginal': 'comfort', 'autoCollapse': True, 'menu': [{'name': 'Marinated Grilled Beef Tri Tip', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Pan Seared Tempeh Piccata Sauce', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Three Cheese Macaroni And Cheese', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Roasted Romanesco', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': "Chef's Table", 'stationOriginal': "chef's table", 'autoCollapse': True, 'menu': [{'name': 'Nacho Bar', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Tortilla Chips', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Tomatillo Chicken', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Achiote Baked Tofu', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Refried Beans', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Cheese Sauce', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Sour Cream, Shredded Cheddar Cheese', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Jalapeños, Olives, Guacamole And Salsa', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Global', 'stationOriginal': 'global', 'autoCollapse': True, 'menu': [{'name': 'Pitzer Korean Tacos', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Korean Style Beef', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Korean Style Chicken', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Korean Style Tofu', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Lime, Cucumber', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Korean Style Slaw, Napa Cabbage, Green Onions, Cilantro, Red Cabbage', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Spicy Sriracha Vegenaise', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Soy Lime Dip Sauce', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Grill', 'stationOriginal': 'grill', 'autoCollapse': True, 'menu': [{'name': 'Market Grill', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chicken Tenders', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Halal Grilled Chicken', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Grass Fed Beef Patties', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Gardein Black Bean Patties', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Hot Dogs', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'French Fries', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Toppings', 'description': 'tomatoes, pickles, lettuce, onions, guacamole, mayo, bacon', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Stocks', 'sta ...

# %%
#claremont mckenna

#print(result_claremont)

claremont_expo = []
claremont_salad = []
claremont_grill = []
claremont_sweets = []
claremont_athome = []
claremont_plant = []
claremont_stock = []
claremont_oven = []
claremont_oasis = []

for menu in result_claremont["response"]["menu"]:
    print(menu)
    day5 = list(filter(lambda x: utc_to_day(x["startTime"]) == curr_date, menu["meals"].values()))
    print(day5)
    for meal in day5:
      if meal['meal'] == 'Lunch':
          print(meal)
          for station in meal['stations']:
            if station['station'] == 'Simply Oasis':
              for menu in station['menu']:
                claremont_oasis.append([menu['name']])
            elif station['station'] == 'Stock Pot':
              for menu in station['menu']:
                claremont_stock.append([menu['name']])
            elif station['station'] == 'Sweets':
              for menu in station['menu']:
                claremont_sweets.append([menu['name']])
            elif station['station'] == '@home':
              for menu in station['menu']:
                claremont_athome.append([menu['name']])
            elif station['station'] == 'Grill':
              for menu in station['menu']:
                claremont_grill.append([menu['name']])
            elif station['station'] == 'Expo':
              for menu in station['menu']:
                claremont_expo.append([menu['name']])
            elif station['station'] == 'Ovens':
              for menu in station['menu']:
                claremont_oven.append([menu['name']])
            elif station['station'] == 'Plant Forward':
              for menu in station['menu']:
                claremont_plant.append([menu['name']])
            
            
  
        
          


print(claremont_grill)
# Out:
# {'date': '2023-03-05', 'time': 1678003200, 'meals': {'brunch': {'meal': 'Brunch', 'startTime': 1678041000, 'endTime': 1678048200, 'stations': [{'station': 'Salad Bar', 'stationOriginal': 'salad bar', 'autoCollapse': True, 'menu': []}, {'station': 'Expo', 'stationOriginal': 'expo', 'autoCollapse': True, 'menu': [{'name': 'Smoothies', 'description': 'blueberries, mango, orange passionfruit | pineapple, mango, strawberry kiwi | made without added sugar | watermelon, cantaloupe, mango, pineapple', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Options', 'stationOriginal': 'options', 'autoCollapse': True, 'menu': [{'name': 'Waffle Bar', 'description': 'house batter, assorted toppings and pancake syrup', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Buttermilk Pancakes', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Biscuits + Gravy', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chicken Strips', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Grill', 'stationOriginal': 'grill', 'autoCollapse': True, 'menu': [{'name': 'Omelet Bar', 'description': 'Glaum Egg Ranch', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Tofu Scramble', 'description': 'Meiji Tofu', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Sweets', 'stationOriginal': 'sweets', 'autoCollapse': True, 'menu': [{'name': 'Sweets', 'description': 'raspberry muffins | chocolate muffins | cinnamon rolls | assorted danishes', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Vegan', 'description': 'chia seed pudding with soy', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Made Without Gluten', 'description': 'muffins | bagels', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Stock Pot', 'stationOriginal': 'stock pot', 'autoCollapse': True, 'menu': [{'name': 'Creamy Yams', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}]}, {'station': 'Simply Oasis', 'stationOriginal': 'simply oasis', 'autoCollapse': True, 'menu': [{'name': 'Roasted Pork', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Rice Pilaf', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Brussel Sprouts', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Breakfast @ Home', 'stationOriginal': 'breakfast @ home', 'autoCollapse': True, 'menu': [{'name': 'Oatmeal', 'description': 'assorted toppings', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Scrambled Cage Free Eggs', 'description': 'oil, salt', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chorizo And Eggs Scramble', 'description': 'cage free eggs, pork chorizo', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Home Fried Potatoes', 'description': 'diced potatoes, onions, bell peppers, salt, oil', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Pork Sausage Patties', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Turkey Links', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Beyond Vegan Sausage Patty', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}]}, 'dinner': {'meal': 'Dinner', 'startTime': 1678062600, 'endTime': 1678069800, 'stations': [{'station': 'Plant Forward', 'stationOriginal': 'plant forward', 'autoCollapse': True, 'menu': [{'name': 'Kung Pao Tofu', 'description': 'tofu, bell peppers, onions, MWG soy sauce, brown sugar, ginger, garlic, veggie stock', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Steamed Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Kidney Beans', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Local Vegetables', 'description': 'VR Green Farms', 'vegan': True, 'v ...
# [{'meal': 'Brunch', 'startTime': 1678041000, 'endTime': 1678048200, 'stations': [{'station': 'Salad Bar', 'stationOriginal': 'salad bar', 'autoCollapse': True, 'menu': []}, {'station': 'Expo', 'stationOriginal': 'expo', 'autoCollapse': True, 'menu': [{'name': 'Smoothies', 'description': 'blueberries, mango, orange passionfruit | pineapple, mango, strawberry kiwi | made without added sugar | watermelon, cantaloupe, mango, pineapple', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Options', 'stationOriginal': 'options', 'autoCollapse': True, 'menu': [{'name': 'Waffle Bar', 'description': 'house batter, assorted toppings and pancake syrup', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Buttermilk Pancakes', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Biscuits + Gravy', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chicken Strips', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Grill', 'stationOriginal': 'grill', 'autoCollapse': True, 'menu': [{'name': 'Omelet Bar', 'description': 'Glaum Egg Ranch', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Tofu Scramble', 'description': 'Meiji Tofu', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Sweets', 'stationOriginal': 'sweets', 'autoCollapse': True, 'menu': [{'name': 'Sweets', 'description': 'raspberry muffins | chocolate muffins | cinnamon rolls | assorted danishes', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Vegan', 'description': 'chia seed pudding with soy', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Made Without Gluten', 'description': 'muffins | bagels', 'vegan': False, 'vegetarian': False, 'calories': 0}]}, {'station': 'Stock Pot', 'stationOriginal': 'stock pot', 'autoCollapse': True, 'menu': [{'name': 'Creamy Yams', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}]}, {'station': 'Simply Oasis', 'stationOriginal': 'simply oasis', 'autoCollapse': True, 'menu': [{'name': 'Roasted Pork', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Rice Pilaf', 'description': '', 'vegan': False, 'vegetarian': True, 'calories': 0}, {'name': 'Brussel Sprouts', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Breakfast @ Home', 'stationOriginal': 'breakfast @ home', 'autoCollapse': True, 'menu': [{'name': 'Oatmeal', 'description': 'assorted toppings', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Scrambled Cage Free Eggs', 'description': 'oil, salt', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Chorizo And Eggs Scramble', 'description': 'cage free eggs, pork chorizo', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Home Fried Potatoes', 'description': 'diced potatoes, onions, bell peppers, salt, oil', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Pork Sausage Patties', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Turkey Links', 'description': '', 'vegan': False, 'vegetarian': False, 'calories': 0}, {'name': 'Beyond Vegan Sausage Patty', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}]}]}, {'meal': 'Dinner', 'startTime': 1678062600, 'endTime': 1678069800, 'stations': [{'station': 'Plant Forward', 'stationOriginal': 'plant forward', 'autoCollapse': True, 'menu': [{'name': 'Kung Pao Tofu', 'description': 'tofu, bell peppers, onions, MWG soy sauce, brown sugar, ginger, garlic, veggie stock', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Steamed Rice', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Kidney Beans', 'description': '', 'vegan': True, 'vegetarian': True, 'calories': 0}, {'name': 'Local Vegetables', 'description': 'VR Green Farms', 'vegan': True, 'vegetarian': True, 'calories': 0}]}, {'station': 'Simply Oasis', 'station ...
# []

# %%
#lunch pandas

import pandas as pd


dfDinner = pd.DataFrame({'frary_dessert': [dessert],'frary_mainline': [mainline], 'frary_expo': [expo], 'frary_grill': [grill],'frary_saladbar': [saladbar],'frary_soup': [soup],'mudd_exhibition': [mudd_exhibition],
                   'mudd_bakery': [mudd_bakery], 'mudd_grill': [mudd_grill],'mudd_saladyogurt': [mudd_saladyogurt], 'mudd_saladstation': [mudd_specialsalad], 'mudd_exhibition':[mudd_exhibition], 'mudd_veggievalley':[mudd_veggievalley], 'mudd_HMCspecialsalad':[mudd_hmcspecialsalad], 'mudd_chefscorner':[mudd_chef], 'mudd_soupbar':[mudd_soupbar],'mudd_simpleservings':[mudd_simpleservings], 'mudd_over':[mudd_oven], 'scripps_salad': [scripps_salad], 
                   'scripps_grill': [scripps_grill],'scripps_sweets': [scripps_sweets], 'scripps_global': [scripps_global], 'scripps_soup': [scripps_soup],'scripps_herbivore' : [scripps_herbivore], 'scripps_oasis':[scripps_oasis], 'scripps_ovens':[scripps_ovens],
                   'scripps_deli': [scripps_deli], 'scripps_deli': [scripps_deli],
                   'pitzer_chefstable': [pitzer_chefstable], 'pitzer_comfort':[pitzer_comfort], 'pitzer_global': [pitzer_global], 'pitzer_stocks':[pitzer_stocks],'pitzer_herbivore' : [pitzer_herbivore], 'pitzer_grill':[pitzer_grill], 
                   'claremont_athome': [claremont_athome], 'claremont_grill': [claremont_grill], 'claremont_options':[claremont_options], 'claremont_sweets':[claremont_sweets], 'claremont_plant':[claremont_plant],'claremont_stock':[claremont_stock],'claremont_oven': [claremont_oven]})

dfDinner
# Out:
#                                        frary_dessert  \
# 0  [[Snickerdoodle Cookies], [German Chocolate Ca...
#
#                                       frary_mainline  \
# 0  [[Carved Roast Turkey], [Cranberry Sauce], [Ve...
#
#                                           frary_expo  \
# 0  [[Vegan "Beef" Miso Braised French Dip Sandwich]]
#
#                                          frary_grill  \
# 0  [[Egg Foo Young], [Grilled Halal Chicken Breast]]
#
#                frary_saladbar                       frary_soup  \
# 0  [[Broccoli Madness Salad]]  [[Corn and Green Chile Bisque]]
#
#   mudd_exhibition                                        mudd_bakery  \
# 0              []  [[Banana Pudding], [Berry Blue Gelatin Parfait...
#
#                                           mudd_grill  \
# 0  [[Mac & Cheese Dog], [Mini Chicken Corndog], [...
#
#                                     mudd_saladyogurt  ... pitzer_stocks  \
# 0  [[Yoplait Low Fat Vanilla Yogurt], [Low Fat St...  ...            []
#
#   pitzer_herbivore                                       pitzer_grill  \
# 0               []  [[Market Grill], [Chicken Tenders], [Halal Gri...
#
#   claremont_athome claremont_grill claremont_options claremont_sweets  \
# 0               []              []                []               []
#
#   claremont_plant claremont_stock claremont_oven
# 0              []              []             []
#
# [1 rows x 39 columns]

# %% [markdown]
# ###

# %% [markdown]
# # Spreadsheets:

# %%
# !pip install gspread==5.7.2
# Out:
# Collecting gspread==5.7.2
#   Downloading gspread-5.7.2-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from gspread==5.7.2) (0.4.6)
# Requirement already satisfied: google-auth>=1.12.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from gspread==5.7.2) (2.13.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from google-auth>=1.12.0->gspread==5.7.2) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from google-auth>=1.12.0->gspread==5.7.2) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from google-auth>=1.12.0->gspread==5.7.2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from google-auth>=1.12.0->gspread==5.7.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from google-auth-oauthlib>=0.4.1->gspread==5.7.2) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread==5.7.2) (0.4.8)
# Requirement already satisfied: requests>=2.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==5.7.2) (2.28.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==5.7.2) (3.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==5.7.2) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==5.7.2) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==5.7.2) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==5.7.2) (3.4)
# Installing collected packages: gspread
# Successfully installed gspread-5.7.2
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
#Breccy
import gspread
from google.oauth2 import service_account

credentials_file = "/work/camp-claremont-eef0a71b208c.json"


creds = service_account.Credentials.from_service_account_file(credentials_file, scopes=["https://www.googleapis.com/auth/spreadsheets"])


gc = gspread.authorize(creds)
sheet_id = "1o6khNUO4GyXMLveWZkcWdqTTUhygudubZKqsgpAiJjA"
sheet = gc.open_by_key(sheet_id).sheet1


new_row = df_breakfast.iloc[0].tolist()
new_row.insert(0, '') # Insert an empty string as the first element of the new_row list
new_row = ['; '.join([str(elem) for elem in sublist]) if isinstance(sublist, list) else str(sublist) for sublist in new_row]
sheet.append_row(new_row, value_input_option='USER_ENTERED')
# Out:
# {'spreadsheetId': '1o6khNUO4GyXMLveWZkcWdqTTUhygudubZKqsgpAiJjA',
#  'tableRange': 'Sheet1!EN9:ER9',
#  'updates': {'spreadsheetId': '1o6khNUO4GyXMLveWZkcWdqTTUhygudubZKqsgpAiJjA',
#   'updatedRange': 'Sheet1!EN10:FL10',
#   'updatedRows': 1,
#   'updatedColumns': 25,
#   'updatedCells': 25}}

# %%
#Gunch

import gspread
from google.oauth2 import service_account

credentials_file = "/work/camp-claremont-eef0a71b208c.json"

creds = service_account.Credentials.from_service_account_file(credentials_file, scopes=["https://www.googleapis.com/auth/spreadsheets"])


gc = gspread.authorize(creds)
sheet_id = "1yyCGD7Nft0_qXmk7FywcK97m4yo3cdnkbsKeeXKUAEY"
sheet = gc.open_by_key(sheet_id).sheet1


new_row = dfLunch.iloc[0].tolist()
new_row.insert(0, '') # Insert an empty string as the first element of the new_row list
new_row = ['; '.join([str(elem) for elem in sublist]) if isinstance(sublist, list) else str(sublist) for sublist in new_row]
sheet.append_row(new_row, value_input_option='USER_ENTERED')
# Out:
# {'spreadsheetId': '1yyCGD7Nft0_qXmk7FywcK97m4yo3cdnkbsKeeXKUAEY',
#  'tableRange': 'Sheet1!A1:AN9',
#  'updates': {'spreadsheetId': '1yyCGD7Nft0_qXmk7FywcK97m4yo3cdnkbsKeeXKUAEY',
#   'updatedRange': 'Sheet1!A10:AN10',
#   'updatedRows': 1,
#   'updatedColumns': 40,
#   'updatedCells': 40}}

# %%
import gspread
from google.oauth2 import service_account

credentials_file = "/work/camp-claremont-eef0a71b208c.json"

creds = service_account.Credentials.from_service_account_file(credentials_file, scopes=["https://www.googleapis.com/auth/spreadsheets"])

gc = gspread.authorize(creds)
sheet_id = "12vL_MrItXFrniW2KyF-gWh9tYjrZ1KNpUSkOSq9emcA"
sheet = gc.open_by_key(sheet_id).sheet1

new_row = dfDinner.iloc[0].tolist()
new_row.insert(0, '') # Insert an empty string as the first element of the new_row list
new_row = ['; '.join([str(elem) for elem in sublist]) if isinstance(sublist, list) else str(sublist) for sublist in new_row]
sheet.append_row(new_row, value_input_option='USER_ENTERED')
# Out:
# {'spreadsheetId': '12vL_MrItXFrniW2KyF-gWh9tYjrZ1KNpUSkOSq9emcA',
#  'tableRange': 'Sheet1!KA9',
#  'updates': {'spreadsheetId': '12vL_MrItXFrniW2KyF-gWh9tYjrZ1KNpUSkOSq9emcA',
#   'updatedRange': 'Sheet1!KA10:LN10',
#   'updatedRows': 1,
#   'updatedColumns': 40,
#   'updatedCells': 40}}

# %%
#Shinner
'''
import gspread
from google.oauth2 import service_account

credentials_file = "/work/camp-claremont-eef0a71b208c.json"

creds = service_account.Credentials.from_service_account_file(credentials_file, scopes=["https://www.googleapis.com/auth/spreadsheets"])


gc = gspread.authorize(creds)
sheet_id = "12vL_MrItXFrniW2KyF-gWh9tYjrZ1KNpUSkOSq9emcA"
sheet = gc.open_by_key(sheet_id).sheet1


new_row = dfDinner.iloc[0].tolist()
new_row = ['; '.join([str(elem) for elem in sublist]) if isinstance(sublist, list) else str(sublist) for sublist in new_row]
sheet.append_row(new_row)
'''
# Out:
# '\nimport gspread\nfrom google.oauth2 import service_account\n\ncredentials_file = "/work/camp-claremont-eef0a71b208c.json"\n\ncreds = service_account.Credentials.from_service_account_file(credentials_file, scopes=["https://www.googleapis.com/auth/spreadsheets"])\n\n\ngc = gspread.authorize(creds)\nsheet_id = "12vL_MrItXFrniW2KyF-gWh9tYjrZ1KNpUSkOSq9emcA"\nsheet = gc.open_by_key(sheet_id).sheet1\n\n\nnew_row = dfDinner.iloc[0].tolist()\nnew_row = [\'; \'.join([str(elem) for elem in sublist]) if isinstance(sublist, list) else str(sublist) for sublist in new_row]\nsheet.append_row(new_row)\n'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2bcc5d52-b4eb-42dd-a50f-c9803ec58156' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
